# %% [markdown]
# # Simple or Single Variate Linear Regression Model

# %% [markdown]
# <img src="Logo.jpg">

# %% [markdown]
# #What is Regression ?
# Regression searches for relationships among variables.
#
# Example--> Salary of an exployee is directly dependent on years of experience and skill set. But how much weightage should be given to experience and how much to the skill set.

# %% [markdown]
# Simple or single-variate linear regression is the simplest case of linear regression with a single independent variable, 𝐱 = 𝑥.

# %% [markdown]
# <img src="Formula.jpg">

# %% [markdown]
# where "m" is the slope , "c" is the intercept, x is the independent variable and y is the dependent variable(predict)
# m=the slope or gradient of a line is a number that describes both the direction and the steepness of the line.
# c=The intercept (often labeled as constant) is the point where the function crosses the y-axis

# %% [markdown]
# <img src="OLS.png">

# %%
#importing the required libs

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing the csv file containing data
dataset=pd.read_csv('salary.csv')
print(dataset.head())
# Out:
#    Exp  Salary
# 0    1   50000
# 1    2   55000
# 2    3   57000
# 3    4   66001
# 4    5   67002

# %%
#Since we have only 1 feature column , separating feature and label into separate variables
X=dataset.iloc[:,:1].values
y=dataset.iloc[:,1].values

# %%
#splitting into test and training set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

#Fitting simple linear regressor to training set
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)

#predicting the test result
print(X_test)
y_pred=regressor.predict(X_test)

#visualizing the training set results
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Linear Regressor Train')
plt.xlabel('Years_of_Exp')
plt.ylabel('Salary')
plt.show()

#visualizing the test set results
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Linear Regressor Test')
plt.xlabel('Years of Exp')
plt.ylabel('Salary')
plt.show()
# Out:
# [[15]
#  [ 7]
#  [11]
#  [17]]

# %% [markdown]
# # Validating the model

# %%
#exp->9, salary-->73005

y_val=regressor.predict([[9.5]])

# %%
y_val
# Out:
# array([70798.00341297])
